# %% [markdown]
# ### Integer type

# %%
1
# Out:
# 1

# %% [markdown]
# ### Float type

# %%
34.
# Out:
# 34.0

# %% [markdown]
# ### Boolean type

# %%
True
# Out:
# True

# %% [markdown]
# ### Float representation is not exact.

# %%
format(.1+.1+.1, '.20f')
# Out:
# '0.30000000000000004441'

# %%
format(.3, '.20f')
# Out:
# '0.29999999999999998890'

# %% [markdown]
# ### Do not compare float with equal operator.

# %%
.1+.1+.1 == .3
# Out:
# False

# %% [markdown]
# ### Comaring two floats:

# %%
abs((.1+.1+.1) - .3)
# Out:
# 5.551115123125783e-17

# %%
if abs((.1+.1+.1) - .3 < .0000001):
    print('Equal')
else:
    print('Not equal')
# Out:
# Equal

# %% [markdown]
# ### Float as integer ratio:

# %%
(.125).as_integer_ratio()
# Out:
# (1, 8)

# %%
(.124).as_integer_ratio()
# Out:
# (1116892707587883, 9007199254740992)

# %% [markdown]
# ### Everything in Python is an Objects
# Have state:

# %%
41
# Out:
# 41

# %% [markdown]
# Have functionality:

# %%
(41).__add__(3)
# Out:
# 44

# %% [markdown]
# ### Some objects are immutable
# Integer, floats, booleans, strings...

# %% [markdown]
# ### Some objects are mutable
# list, dictionaries, sets...

# %% [markdown]
# ### Do not use label it was alredy defined by Python:

# %%
fl = float(5)
fl, type(fl)
# Out:
# (5.0, float)

# %%
float = 3
float, type(float)
# Out:
# (3, int)

# %%
del float

# %%
fl = float(3)
fl, type(float)
# Out:
# (3.0, type)

# %% [markdown]
# ### Operators

# %%
# Division
5/2
# Out:
# 2.5

# %%
# Modulos
5.2%2
# Out:
# 1.2000000000000002

# %%
# power
2**3
# Out:
# 8

# %%
# Integer division
7.1//2
# Out:
# 3.0

# %%
type(3)
# Out:
# int

# %% [markdown]
# ### Identity operator
# is operator check if is the same memory.  is operator check if is the same memory.  is operator check if is the same memory.  is operator check if is the same memory.  is operator check if is the same memory.  is operator check if is the same memory.
# For small integers Python point to the same memory, for big integer not.

# %%
a = 3
b = 3
a is b, id(a), id(b)
# Out:
# (True, 93987351567216, 93987351567216)

# %%
a = 3
b = 3.0
a is b, id(a), id(b)
# Out:
# (False, 93987351567216, 139959342818448)

# %%
a = 500
b = 500
d is e, id(a), id(b)
# Out:
# (False, 139959342819248, 139959342818288)

# %% [markdown]
# ### Equal operator

# %%
1 == 1
# Out:
# True

# %%
(1).__eq__(1)
# Out:
# True

# %% [markdown]
# ### Short circuit in comparassion

# %%
a = 20
b = 0
b != 0 and 1 / b
# Out:
# False

# %%
a = 20
b = 1
b != 0 and 1 / b
# Out:
# 1.0
