# %% [markdown]
# # Dictionary

# %%
d = {'a': 1, 'b': 2}

# %%
type(d)
# Out:
# dict

# %%
d['a']
# Out:
# 1

# %%
d['c']=3
d
# Out:
# {'a': 1, 'b': 2, 'c': 3}

# %%
del d['a']
d
# Out:
# {'b': 2, 'c': 3}

# %% [markdown]
# # Discovery if it is hashable

# %%
hash('asdf')
# Out:
# -5990743614646467618

# %%
hash([1,2,3])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 hash([1,2,3])
#
# TypeError: unhashable type: 'list'

# %%
hash((1,2,3))
# Out:
# 529344067295497451

# %% [markdown]
# # Dictionary with all defined

# %%
globals()
# Out:
# {'__name__': '__main__',
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['',
#   "d = {'a': 1, 'b': 2}",
#   'type(d)',
#   "d['a']",
#   "d['c']=3\nd",
#   "del d['a']\nd",
#   "hash('asdf')",
#   'hash([1,2,3])',
#   'hash((1,2,3))',
#   'globals()'],
#  '_oh': {2: dict,
#   3: 1,
#   4: {'b': 2, 'c': 3},
#   5: {'b': 2, 'c': 3},
#   6: -5990743614646467618,
#   8: 529344067295497451},
#  '_dh': [PosixPath('/home/douglasmg7/code/python-fundamentals')],
#  'In': ['',
#   "d = {'a': 1, 'b': 2}",
#   'type(d)',
#   "d['a']",
#   "d['c']=3\nd",
#   "del d['a']\nd",
#   "hash('asdf')",
#   'hash([1,2,3])',
#   'hash((1,2,3))',
#   'globals()'],
#  'Out': {2: dict,
#   3: 1,
#   4: {'b': 2, 'c': 3},
#   5: {'b': 2, 'c': 3},
#   6: -5990743614646467618,
#   8: 529344067295497451},
#  'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x7f7b086b46e0>>,
#  'exit': <IPython.core.autocall.ZMQExitAutocall at 0x7f7b086b63c0>,
#  'quit': <IPython.core.autocall.ZMQExitAutocall at 0x7f7b086b63c0>,
#  'open': <function _io.open(file, mode='r', buffering=-1, encoding=None, errors=None, newline=None, closefd=True, opener=None)>,
#  '_': 529344067295497451,
#  '__': -5990743614646467618,
#  '___': {'b': 2, 'c': 3},
#  '__session__': '/home/douglasmg7/code/python-fundamentals/008-Dictionary.ipynb',
#  '_i': 'hash((1,2,3))',
#  '_ii': 'hash([1,2,3])',
#  '_iii': "hash('asdf')",
#  '_i1': "d = {'a': 1, 'b': 2}",
#  'd': {'b': 2, 'c': 3},
#  '_i2': 'type(d)',
#  '_2': dict,
#  '_i3': "d['a']",
#  '_3': 1,
#  '_i4': "d['c']=3\nd",
#  '_4': {'b': 2, 'c': 3},
#  '_i5': "del d['a']\nd",
#  '_5': {'b': 2, 'c': 3},
#  '_i6': "hash('asdf')",
#  '_6': -5990743614646467618,
#  '_i7': 'hash([1,2,3])',
#  '_i8': 'hash((1,2,3))',
#  '_8': 529344067295497451,
#  '_i9': 'globals()'}

# %%
type(globals())
# Out:
# dict

# %%
globals()['d']
# Out:
# {'b': 2, 'c': 3}

# %% [markdown]
# ## Iterate

# %%
d = {'a': 1, 'b': 2, 'c': 3, 'd': 4}

# %%
for val in d:
    print(val)
# Out:
# a
# b
# c
# d

# %%
d.keys()
# Out:
# dict_keys(['a', 'b', 'c', 'd'])

# %%
for v in d.keys():
    print(v)
# Out:
# a
# b
# c
# d

# %%
d.values()
# Out:
# dict_values([1, 2, 3, 4])

# %%
for key in d.values():
    print(key)
# Out:
# 1
# 2
# 3
# 4

# %%
d.items()

# %%
for pair in d.items():
    print(pair)
# Out:
# ('a', 1)
# ('b', 2)
# ('c', 3)
# ('d', 4)

# %%
d.keys()
# Out:
# dict_keys(['a', 'b', 'c', 'd'])

# %% [markdown]
# ## Check if key exist

# %%
'b' in d
# Out:
# True

# %%
'a' not in d
# Out:
# False

# %% [markdown]
# ## Clear the dictionary

# %%
d.clear()
d
# Out:
# {}

# %% [markdown]
# ## Creating from keys

# %%
d = dict.fromkeys('asdf', 0)
d
# Out:
# {'a': 0, 's': 0, 'd': 0, 'f': 0}

# %% [markdown]
# ## Get a default value if key not exist

# %%
d.get('h', 5)
# Out:
# 5

# %%
result = d.get('h')
result == None
# Out:
# True

# %% [markdown]
# ## Merge dict

# %%
d1 = {'a': 1, 'b': 2}
d2 = {'b': 22, 'c': 3}
d1.update(d2)
print(d1)
print(d2)
# Out:
# {'a': 1, 'b': 22, 'c': 3}
# {'b': 22, 'c': 3}

# %% [markdown]
# ## Creating a list from a dict

# %%
l = ['asdf', 'sdfg', 'dfgh', 'fghj']
d = dict.fromkeys(l, 2)
print(d)
print(list(d))
print(list(d.values()))
# Out:
# {'asdf': 2, 'sdfg': 2, 'dfgh': 2, 'fghj': 2}
# ['asdf', 'sdfg', 'dfgh', 'fghj']
# [2, 2, 2, 2]
