# %% [markdown]
# ### Modules and Imports

# %%
# PyPI - Python Package Index
# pypi.org

# %%
import math

# %%
math.sqrt(4)
# Out:
# 2.0

# %%
math
# Out:
# <module 'math' from '/home/douglasmg7/miniconda3/envs/pf/lib/python3.14/lib-dynload/math.cpython-314-x86_64-linux-gnu.so'>

# %%
math.sqrt
# Out:
# <function math.sqrt(x, /)>

# %%
# ?math
# Out:
# Type:        module
# String form: <module 'math' from '/home/douglasmg7/miniconda3/envs/pf/lib/python3.14/lib-dynload/math.cpython-314-x86_64-linux-gnu.so'>
# File:        ~/miniconda3/envs/pf/lib/python3.14/lib-dynload/math.cpython-314-x86_64-linux-gnu.so
# Docstring:
# This module provides access to the mathematical functions
# defined by the C standard.

# %%
help(math)
# Out:
# Help on module math:
#
# NAME
#     math
#
# MODULE REFERENCE
#     https://docs.python.org/3.14/library/math#module-math
#
#     The following documentation is automatically generated from the Python
#     source files.  It may be incomplete, incorrect or include features that
#     are considered implementation detail and may vary between Python
#     implementations.  When in doubt, consult the module reference at the
#     location listed above.
#
# DESCRIPTION
#     This module provides access to the mathematical functions
#     defined by the C standard.
#
# FUNCTIONS
#     acos(x, /)
#         Return the arc cosine (measured in radians) of x.
#
#         The result is between 0 and pi.
#
#     acosh(x, /)
#         Return the inverse hyperbolic cosine of x.
#
#     asin(x, /)
#         Return the arc sine (measured in radians) of x.
#
#         The result is between -pi/2 and pi/2.
#
#     asinh(x, /)
#         Return the inverse hyperbolic sine of x.
#
#     atan(x, /)
# ...

# %%
math.pi
# Out:
# 3.141592653589793

# %%
help(math.factorial)
# Out:
# Help on built-in function factorial in module math:
#
# factorial(n, /)
#     Find n!.

# %%
# ?math.factorial
# Out:
# Signature: math.factorial(n, /)
# Docstring: Find n!.
# Type:      builtin_function_or_method

# %%
# / in parameter list means that the parameters before / must be positional only.

# %%
import random as rdn

# %%
rdn.randint(1,30)
# Out:
# 2

# %%
import os

# %%
os
# Out:
# <module 'os' from '/home/douglasmg7/miniconda3/envs/pf/lib/python3.14/os.py'>

# %%
os.path
# Out:
# <module 'posixpath' from '/home/douglasmg7/miniconda3/envs/pf/lib/python3.14/posixpath.py'>

# %%
os.path.curdir
# Out:
# '.'

# %%
type(os.path.curdir)
# Out:
# str

# %%
os.path.abspath('.')
# Out:
# '/home/douglasmg7/code/python-fundamentals'

# %%
from fractions import Fraction

# %%
fr = Fraction(1/8)

# %%
fr
# Out:
# Fraction(1, 8)

# %%
float(fr)
# Out:
# 0.125

# %%
from math import e, pi

# %%
e, pi
# Out:
# (2.718281828459045, 3.141592653589793)
